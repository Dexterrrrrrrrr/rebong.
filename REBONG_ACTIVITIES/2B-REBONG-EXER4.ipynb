# %% [markdown]
# Import Libraries

# %%
import pandas as pd #Data Manipulation
import numpy as np # Numerical operation
import matplotlib.pyplot as plt #Data Visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression #Data Modeling
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 1.LOAD DATA

# %%
data_path = ("Lesson_4_student_grades_dataset.csv")
dataset = pd.read_csv(data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-fb35902d6686> in <cell line: 2>()
#       1 data_path = ("Lesson_4_student_grades_dataset.csv")
# ----> 2 dataset = pd.read_csv(data_path)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
x = dataset.drop('Grades', axis=1)
y = dataset [('Grades')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb047c44edc4> in <cell line: 1>()
# ----> 1 x = dataset.drop('Grades', axis=1)
#       2 y = dataset [('Grades')]
#
# NameError: name 'dataset' is not defined

# %%
data = pd.read_csv("Lesson_4_student_grades_dataset.csv")
data.head()

# %% [markdown]
# 2. Data Processing

# %%
print(dataset)

x= dataset.drop('Grades', axis=1)
y = dataset [('Grades')]
# Out:
#      Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0          4.370861              75.553988             63.085284
# 1          9.556429              86.257028             62.348940
# 2          7.587945              96.188375             95.312729
# 3          6.387926              91.966747             62.477310
# 4          2.404168              94.196834             63.597486
# ..              ...                    ...                   ...
# 995        1.824239              89.708655             93.264788
# 996        9.255822              98.698439             57.863660
# 997        2.231368              72.068740             65.489393
# 998        9.552136              71.711642             64.502277
# 999        5.014052              78.465612             93.570702
#
#      Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                             0              24.325977  31.494329
# ...

# %% [markdown]
# 3. Train-test split

# %%
Previous_Exam_Scores_train, Previous_Exam_Scores_test, Grades_train, Grades_test = train_test_split(x,y, test_size = 0.2, random_state = 42)
model = LinearRegression()
model.fit(Previous_Exam_Scores_train, Grades_train)
# Out:
# LinearRegression()

# %% [markdown]
# 4. Linear Regression Model

# %%
a = dataset[['Hours_of_Study']]
e = dataset[['Attendance_Percentage']]
i = dataset[['Previous_Exam_Scores']]
o = dataset[['Extracurricular_Activities']]
u = dataset[['Travel_Time_to_School']]
Y = dataset[['Grades']]

model1 = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()
model4 = LinearRegression()
model5 = LinearRegression()

model1.fit(a, Y)
model2.fit(b, Y)
model3.fit(c, Y)
model4.fit(d, Y)
model5.fit(e, Y)

# %%
plt.scatter(a, Y)
plt.plot(a, model1.predict(a), color = 'red')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title("Linear Regression")
plt.show()

plt.scatter(b, Y)
plt.plot(b, model2.predict(e), color = 'black')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title("Linear Regression")
plt.show()

plt.scatter(c, Y)
plt.plot(c, model3.predict(i), color = 'green')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title("Linear Regression")
plt.show()

plt.scatter(d, Y)
plt.plot(d, model4.predict(o), color = 'purple')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title("Linear Regression")
plt.show()

plt.scatter(e, Y)
plt.plot(e, model5.predict(e), color = 'blue')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# 5.Model training

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 6. Predict

# %%
new_data = np.array([[2,70,85,1,50]])

prediction = model.predict(new_data)
print(f"predicted Grade:  {prediction[0]}")
# Out:
# predicted Grade:  49.999999999999766
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 7. Features and importance analysis

# %%
print("Hours of Study")
slope = model1.coef_[0]
intercept = model1.intercept_
print('Slope', slope)
print('Intercept', intercept)
print(" ")
print("Attendance Percentage")
slop = model2.coef_[0]
intercep = model2.intercept_
print('Slope', slop)
print('Intercept', intercep)
print(" ")
print("Previous Exam Scores")
slo = model3.coef_[0]
interce = model3.intercept_
print('Slope', slo)
print('Intercept', interce)
print(" ")
print("ExtraCurricular Activities")
sl = model4.coef_[0]
interc = model4.intercept_
print('Slope', sl)
print('Intercept', interc)
print(" ")
print("Travel Time to School")
s = model5.coef_[0]
inter = model5.intercept_
print('Slope', s)
print('Intercept', inter)
# Out:
# Hours of Study
# Slope [0.31185559]
# Intercept [34.50375609]
#
# Attendance Percentage
# Slope [0.23095043]
# Intercept [16.51220848]
#
# Previous Exam Scores
# Slope [0.2556363]
# Intercept [16.98814303]
#
# ExtraCurricular Activities
# Slope [5.28155266]
# Intercept [33.59837253]
#
# Travel Time to School
# Slope [0.23095043]
# Intercept [16.51220848]

# %% [markdown]
# 8. Discuss

# %%
report = """

          One prominent factor impacting grades is the student themself.
          Prior academic performance serves as a foundation, with students
          exhibiting strong results in earlier courses often excelling in subsequent ones.
          However, motivation and engagement play an equally vital role. Intrinsically motivated students,
          driven by a genuine desire to learn, are more likely to dedicate the time and effort required for success.
          Additionally, recognizing and catering to diverse learning styles and preferences is essential.
          Visual, auditory, and kinesthetic learners each benefit from different approaches,
          and adapting instructional methods to these variations can unlock understanding and enhance performance.
"""
print(report)
# Out:
#           One prominent factor impacting grades is the student themself.
#           Prior academic performance serves as a foundation, with students
#           exhibiting strong results in earlier courses often excelling in subsequent ones.
#           However, motivation and engagement play an equally vital role. Intrinsically motivated students,
#           driven by a genuine desire to learn, are more likely to dedicate the time and effort required for success.
#           Additionally, recognizing and catering to diverse learning styles and preferences is essential.
#           Visual, auditory, and kinesthetic learners each benefit from different approaches,
#           and adapting instructional methods to these variations can unlock understanding and enhance performance.

# %% [markdown]
# 9.Scenario Extension

# %%
report = """
        While traditional factors like family background and teacher quality influence grades,
student success can also be impacted by unforeseen elements. Peer pressure and social dynamics
can motivate or distract students. Mental and physical well-being play a crucial role, as students
facing challenges in these areas may struggle to perform academically. The "hidden curriculum"
of implicit messages within the school environment can also shape student motivation and achievement.
Finally, unexpected life events can significantly disrupt learning. Recognizing these diverse influences
allows educators to create more holistic support systems and foster a learning environment that empowers
 all students to succeed.
"""
print(report)
# Out:
# While traditional factors like family background and teacher quality influence grades,
# student success can also be impacted by unforeseen elements. Peer pressure and social dynamics
# can motivate or distract students. Mental and physical well-being play a crucial role, as students
# facing challenges in these areas may struggle to perform academically. The "hidden curriculum"
# of implicit messages within the school environment can also shape student motivation and achievement.
# Finally, unexpected life events can significantly disrupt learning. Recognizing these diverse influences
# allows educators to create more holistic support systems and foster a learning environment that empowers
#  all students to succeed.
